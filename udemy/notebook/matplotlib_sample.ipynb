# %%
# %matplotlib inline
import japanize_matplotlib
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
lena_img = Image.open('pil/test.jpg')
plt.imshow(lena_img)

# %%
lena_arr = np.array(lena_img)
lena_arr.shape
# Out:
# (225, 225, 3)

# %%
lena_arr[100][100]
# Out:
# array([165, 103, 154], dtype=uint8)

# %%
plt.plot([100,100],[200,100],'ro:')
plt.imshow(lena_img)

# %%
plt.plot([100,100],[175,100],'r')
plt.plot([100,160],[100,100],'r')
plt.plot([160,160],[175,100],'r')
plt.plot([160,100],[175,175],'r')
plt.imshow(lena_img)

# %%
plt.plot([1,2,3,4],[2,4,6,8])
plt.ylabel('Y')
plt.xlabel('X')
plt.show()

# %%
x = np.arange(1,10,1)
y1 = 2 * x
y2 = x ** 2
plt.plot(x,y1,'ko-', label='y1')
plt.plot(x,y2,'b*--', label='y2')
plt.title('title')
plt.legend()
plt.show()

# %%
x = np.arange(1,10,1)
y1 = 2 * x
y2 = x ** 2
y2
# Out:
# array([ 1,  4,  9, 16, 25, 36, 49, 64, 81], dtype=int32)

# %%
x = np.arange(1,5,1)
y = x ** 2
objects = ['A','B','C','D']
plt.bar(x,y)
plt.title('ここに題を入れる')
plt.xticks(x,objects)
plt.show()

# %%
x = np.random.rand(20)
y = np.random.rand(20)
area = x * 50
plt.scatter(x,y,s=area,c='r')
plt.show()
